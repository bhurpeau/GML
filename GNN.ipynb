# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import HeteroData
from torch_geometric.nn import SAGEConv, to_hetero
import pandas as pd
import numpy as np
import networkx as nx
import community as community_louvain # Pour l'algorithme de Louvain
import geopandas as gpd
from shapely.geometry import Point 
from shapely.ops import transform 
from sklearn.preprocessing import MinMaxScaler

# %%
from src.utils import telecharger_donnees_plu, load_and_prepare_real_data, perform_semantic_sjoin
from src.hetero import HeteroGNN

# %%
doc_urba = gpd.read_file("data/wfs_du.gpkg",layer='zone_urba')

# %%
doc_urba = doc_urba[['gid','partition','libelle','libelong','typezone','geometry']].copy()

# %%
doc_urba.crs ='4326'

# %%
doc_urba = doc_urba.to_crs(2154)

# %%
df_bat = gpd.read_file('data/BDT_3-5_GPKG_LAMB93_D092-ED2025-06-15.gpkg', layer='batiment')

# %%
df_parcelles = gpd.read_file('data/cadastre-92-parcelles.json')

# %%
# ept_92 = ['200057990', '200057974', '200057982','200057966', '92026', '92033','92035','92044','92050','92051','92062','92063','92064','92073','92076']
# gdf_usage_sol_92 = gpd.GeoDataFrame()
# for CODE_INSEE in ept_92:
#     gdf_usage_sol = telecharger_donnees_plu(CODE_INSEE)
#     if gdf_usage_sol is not None and not gdf_usage_sol.empty:
#         gdf_usage_sol = gdf_usage_sol[['gid','partition','libelle','libelong','typezone','geometry']].copy()
#         gdf_usage_sol_92 = pd.concat([gdf_usage_sol_92,gdf_usage_sol],axis=0)
# Out:
# Succès de la requête, mais 0 zones retournées. 200057982 n'est peut-être couverte par un PLU/PLUI
# Succès de la requête, mais 0 zones retournées. 92033 n'est peut-être couverte par un PLU/PLUI

# %%
df_parcelles['superficie'] = df_parcelles.to_crs(2154).area

# %%
gdf_par = perform_semantic_sjoin(df_parcelles, gdf_usage_sol_92)
# Out:
# Reprojection des Parcelles vers EPSG:2154...
# Reprojection des Zones PLU vers EPSG:2154...
# Calcul du point représentatif des Parcelles (point garanti dans la géométrie)...
# Exécution de la jointure spatiale (Parcelle.ReprensentativePoint WITHIN Zone PLU)...

# %%
gdf_par = gpd.GeoDataFrame(
        gdf_par, 
        geometry=gdf_par['geometry'], 
        crs="EPSG:2154"
    )

# %%
gdf_bat = df_bat[['cleabs','hauteur','geometry']].copy()

# %%
gdf_bat['surface'] = gdf_bat.force_2d().area

# %%
gdf_bat['geometry'] = gdf_bat['geometry'].force_2d()

# %%
df_bat
# Out:
#                           cleabs          nature                 usage_1  \
# 0       BATIMENT0000000329826060  Indifférenciée  Commercial et services
# 1       BATIMENT0000000329826061  Indifférenciée  Commercial et services
# 2       BATIMENT0000000329826062  Indifférenciée  Commercial et services
# 3       BATIMENT0000000329826063  Indifférenciée  Commercial et services
# 4       BATIMENT0000000329826074  Indifférenciée                 Sportif
# ...                          ...             ...                     ...
# 691546  BATIMENT0000000329742062  Indifférenciée  Commercial et services
# 691547  BATIMENT0000000329742063  Indifférenciée  Commercial et services
# 691548  BATIMENT0000000329742064  Indifférenciée  Commercial et services
# 691549  BATIMENT0000000329742066  Indifférenciée  Commercial et services
# 691550  BATIMENT0000000329742067  Indifférenciée  Commercial et services
#
#        usage_2  construction_legere etat_de_l_objet           date_creation  \
# 0         None                False      En service 2013-11-22 14:36:46.100
# 1         None                False      En service 2013-11-22 14:36:46.100
# 2         None                False      En service 2013-11-22 14:36:46.100
# 3         None                False      En service 2013-11-22 14:36:46.100
# 4         None                False      En service 2013-11-22 14:44:32.253
# ...        ...                  ...             ...                     ...
# 691546    None                False      En service 2013-11-20 10:52:27.838
# 691547    None                False      En service 2013-11-20 10:52:27.838
# 691548    None                False      En service 2013-11-20 10:52:27.838
# 691549    None                False      En service 2013-11-20 10:52:30.091
# 691550    None                False      En service 2013-11-20 10:52:30.091
#
#              date_modification date_d_apparition date_de_confirmation  ...  \
# 0      2018-12-03 21:01:36.714              None                  NaT  ...
# 1      2018-12-03 21:01:36.714              None                  NaT  ...
# 2      2018-12-03 21:01:36.714              None                  NaT  ...
# 3      2018-12-03 21:01:36.714              None                  NaT  ...
# 4      2017-12-20 14:55:38.575              None           2013-01-01  ...
# ...                        ...               ...                  ...  ...
# 691546 2018-12-03 19:55:36.025              None                  NaT  ...
# 691547 2018-12-03 19:55:36.025              None                  NaT  ...
# 691548 2018-12-03 19:55:36.025              None           2016-01-01  ...
# 691549 2018-12-03 21:15:12.040              None                  NaT  ...
# 691550 2018-12-03 21:15:12.040              None           2013-01-01  ...
#
#        materiaux_de_la_toiture hauteur altitude_minimale_sol  \
# 0                         None     4.8                  29.0
# 1                         None     4.8                  29.0
# 2                         None     4.8                  29.0
# 3                         None    19.3                  27.9
# 4                         None     4.5                  28.2
# ...                        ...     ...                   ...
# 691546                    None    15.3                  98.8
# 691547                    None     4.9                  98.8
# 691548                    None     4.9                  98.8
# 691549                    None    11.7                  36.1
# 691550                    None    11.7                  36.1
#
#        altitude_minimale_toit  altitude_maximale_toit  altitude_maximale_sol  \
# 0                        33.8                     NaN                    NaN
# 1                        33.8                     NaN                    NaN
# 2                        33.8                     NaN                    NaN
# 3                         NaN                     NaN                    NaN
# 4                         NaN                     NaN                    NaN
# ...                       ...                     ...                    ...
# 691546                  114.1                     NaN                    NaN
# 691547                  103.7                   106.0                   99.5
# 691548                  103.7                     NaN                    NaN
# 691549                   47.8                     NaN                    NaN
# 691550                   47.8                     NaN                    NaN
#
#         origine_du_batiment  appariement_fichiers_fonciers identifiants_rnb  \
# 0                  Cadastre                           None     CGRDXG5M86K6
# 1                  Cadastre                           None     M2A1DXRFC24E
# 2                  Cadastre                           None     Y4EGQR8CJABN
# 3         Imagerie aérienne                           None     6KRE9DN597XW
# 4         Imagerie aérienne                           None     MYH2T9PMH7HS
# ...                     ...                            ...              ...
# 691546             Cadastre                           None     XVXAKK7ABTMB
# 691547             Cadastre                           None     3S88EY3HZ2HJ
# 691548             Cadastre                           None     G5FN44Z5B6NX
# 691549    Imagerie aérienne                           None     SC93659MPR1A
# 691550    Imagerie aérienne                           None     6CTFCTZJD44Y
#
#                                                  geometry
# 0       MULTIPOLYGON Z (((640242.8 6865948.5 33.8, 640...
# 1       MULTIPOLYGON Z (((640105.5 6865894.8 33.8, 640...
# 2       MULTIPOLYGON Z (((640116.9 6865887.7 33.8, 640...
# 3       MULTIPOLYGON Z (((640125.8 6865891.7 47.2, 640...
# 4       MULTIPOLYGON Z (((638592.3 6864340.5 32.7, 638...
# ...                                                   ...
# 691546  MULTIPOLYGON Z (((643154.2 6857844 114.1, 6431...
# 691547  MULTIPOLYGON Z (((643128.2 6857845.5 103.7, 64...
# 691548  MULTIPOLYGON Z (((643158.7 6857809.7 103.7, 64...
# 691549  MULTIPOLYGON Z (((644106 6861101.3 47.8, 64411...
# 691550  MULTIPOLYGON Z (((644094 6861091.5 47.8, 64410...
#
# [691551 rows x 29 columns]

# %%
df_adr = pd.read_csv('data/adresses-92.csv', delimiter=';')
# Out:
# /tmp/ipykernel_5992/3451560825.py:1: DtypeWarning: Columns (16,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_adr = pd.read_csv('data/adresses-92.csv', delimiter=';')

# %%
gdf_adr = gpd.GeoDataFrame(
    df_adr[['id','lon','lat','cad_parcelles']], 
    geometry=gpd.points_from_xy(df_adr['lon'], df_adr['lat']), 
    crs="EPSG:4326"
)

# %%
sjoin_geom = gpd.sjoin(gdf_bat[['cleabs', 'geometry']].to_crs(2154), gdf_par[['id', 'geometry']].to_crs(2154), how='left', predicate='intersects', lsuffix='bat', rsuffix='par')

# %%
sjoin_geom
# Out:
#                           cleabs  \
# 0       BATIMENT0000000329826060
# 1       BATIMENT0000000329826061
# 2       BATIMENT0000000329826062
# 3       BATIMENT0000000329826063
# 4       BATIMENT0000000329826074
# ...                          ...
# 691547  BATIMENT0000000329742063
# 691548  BATIMENT0000000329742064
# 691549  BATIMENT0000000329742066
# 691549  BATIMENT0000000329742066
# 691550  BATIMENT0000000329742067
#
#                                                  geometry  index_par  \
# 0       MULTIPOLYGON (((640242.8 6865948.5, 640263 686...   153563.0
# 1       MULTIPOLYGON (((640105.5 6865894.8, 640110.7 6...   153563.0
# 2       MULTIPOLYGON (((640116.9 6865887.7, 640125.8 6...   153563.0
# 3       MULTIPOLYGON (((640125.8 6865891.7, 640142.4 6...   153563.0
# 4       MULTIPOLYGON (((638592.3 6864340.5, 638585.6 6...   159742.0
# ...                                                   ...        ...
# 691547  MULTIPOLYGON (((643128.2 6857845.5, 643130.9 6...     6405.0
# 691548  MULTIPOLYGON (((643158.7 6857809.7, 643161 685...     6405.0
# 691549  MULTIPOLYGON (((644106 6861101.3, 644116 68611...    24469.0
# 691549  MULTIPOLYGON (((644106 6861101.3, 644116 68611...    24531.0
# 691550  MULTIPOLYGON (((644094 6861091.5, 644103.8 686...    24469.0
#
#                     id
# 0       92050000CX0305
# 1       92050000CX0305
# 2       92050000CX0305
# 3       92050000CX0305
# 4       92063000BP0041
# ...                ...
# 691547  92048000AB0455
# 691548  92048000AB0455
# 691549  920120000J0083
# 691549  920120000J0115
# 691550  920120000J0083
#
# [915542 rows x 4 columns]

# %%
data = HeteroData()
data['adresse'].x = adr_x
data['bâtiment'].x = bat_x
data['parcelle'].x = par_x

# Relations
data['adresse', 'accès', 'bâtiment'].edge_index = edge_index_ab
data['bâtiment', 'appartient', 'parcelle'].edge_index = edge_index_bp
data['bâtiment', 'appartient', 'parcelle'].edge_attr = edge_attr_bp 

print(f"Structure du Graphe créée. Nœuds: {len(data['bâtiment'].x)} | Arêtes B->P: {data['bâtiment', 'appartient', 'parcelle'].num_edges}")
# Out:
# Structure du Graphe créée. Nœuds: 691551 | Arêtes B->P: 0

# %%
print("\n--- 2. Passage de Messages GNN (Création d'Embeddings) ---")
    
HIDDEN_CHANNELS = 64
OUT_CHANNELS = 32

metadata = data.metadata() 
model = HeteroGNN(metadata, hidden_channels=HIDDEN_CHANNELS, out_channels=OUT_CHANNELS)

edge_attr_dict = {
    ('bâtiment', 'appartient', 'parcelle'): data['bâtiment', 'appartient', 'parcelle'].edge_attr
}

x_dict = model(data.x_dict, data.edge_index_dict, edge_attr_dict)

bat_embeddings = x_dict['bâtiment']
# Out:
# --- 2. Passage de Messages GNN (Création d'Embeddings) ---
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
