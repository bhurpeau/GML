# %%
import fiona 
WFS_ENDPOINT = "https://data.geopf.fr/wfs/ows" 
PLU_LAYER_NAME = "wfs_du:zone_urba" 


def telecharger_donnees_plu(insee_code):
    partition_value = f'DU_{insee_code}'
    cql_filter = f"partition='{partition_value}'"
    
    wfs_request_url = (
        f'WFS:{WFS_ENDPOINT}?service=WFS&request=GetFeature&typename={PLU_LAYER_NAME}&version=2.0.0'
        f'&outputFormat=json&cql_filter={cql_filter}'
    )
    
    print(f"Téléchargement WFS pour INSEE {insee_code} en cours...")
    
    try:
        # Utilisation d'un timeout pour les grands serveurs
        gdf_plu_zones = gpd.read_file(wfs_request_url) 
        
        if gdf_plu_zones.empty:
             print("Succès de la requête, mais 0 zones retournées. La commune est peut-être couverte par un PLUI non filtrable par INSEE.")
             return None
             
        print(f"Succès ! {len(gdf_plu_zones)} zones PLU téléchargées.")
        return gdf_plu_zones

    except Exception as e:
        print(f"Échec critique du WFS : {e}")
        return None

# %%
ept_92 = ['200057990',
'200057974',
'200057982',
'200057966',
'92026',
'92033',
'92035',
'92044',
'92050',
'92051',
'92062',
'92063',
'92064',
'92073',
'92076']
gdf_usage_sol_92 = gpd.GeoDataFrame()
for CODE_INSEE in ept_92:
    gdf_usage_sol = telecharger_donnees_plu(CODE_INSEE)
    if gdf_usage_sol is not None and not gdf_usage_sol.empty:
        gdf_usage_sol = gdf_usage_sol[['gid','partition','libelle','libelong','typezone']].copy()
        gdf_usage_sol_92 = pd.concat([gdf_usage_sol_92,gdf_usage_sol],axis=0)
# Out:
# Téléchargement WFS pour INSEE 200057990 en cours...
# Succès ! 894 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 200057974 en cours...
# Succès ! 454 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 200057982 en cours...
# Succès de la requête, mais 0 zones retournées. La commune est peut-être couverte par un PLUI non filtrable par INSEE.
# Téléchargement WFS pour INSEE 200057966 en cours...
# Succès ! 974 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92026 en cours...
# Succès ! 52 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92033 en cours...
# Succès de la requête, mais 0 zones retournées. La commune est peut-être couverte par un PLUI non filtrable par INSEE.
# Téléchargement WFS pour INSEE 92035 en cours...
# Succès ! 51 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92044 en cours...
# Succès ! 13 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92050 en cours...
# Succès ! 134 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92051 en cours...
# Succès ! 54 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92062 en cours...
# Succès ! 46 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92063 en cours...
# Succès ! 143 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92064 en cours...
# Succès ! 92 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92073 en cours...
# Succès ! 55 zones PLU téléchargées.
# Téléchargement WFS pour INSEE 92076 en cours...
# Succès ! 39 zones PLU téléchargées.

# %%
gdf_usage_sol_92
# Out:
#         gid     partition libelle  \
# 0   3080913  DU_200057990  UAb4e7
# 1   3080915  DU_200057990  UAb6e7
# 2   3080884  DU_200057990  UEp6z1
# 3   3080889  DU_200057990   UR4h3
# 4   3080932  DU_200057990  UMs6d6
# ..      ...           ...     ...
# 34  1384400      DU_92076     ULa
# 35  1384401      DU_92076     ULa
# 36  1384386      DU_92076      UL
# 37  1384387      DU_92076      UL
# 38  1384389      DU_92076     ULa
#
#                                              libelong typezone
# 0   Secteur économique dédié aux activités tertiaires        U
# 1   Secteur économique dédié aux activités tertiaires        U
# 2                  Zone réservée aux parcs et squares        U
# 3                     Secteur à dominante résidentiel        U
# 4      Secteur de grande mixité de fonctions urbaines        U
# ..                                                ...      ...
# 34  Secteur qui correspond aux constructions et in...        U
# 35  Secteur qui correspond aux constructions et in...        U
# 36  Zone d'équipements principalement constituée d...        U
# 37  Zone d'équipements principalement constituée d...        U
# 38  Secteur qui correspond aux constructions et in...        U
#
# [3001 rows x 5 columns]
